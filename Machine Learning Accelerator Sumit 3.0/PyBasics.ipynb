# %% [markdown]
# My First Program

# %%
print("Hello, world")
#print() Ctrl+Enter
# Out:
# Hello, world

# %% [markdown]
# x=27

# %%
x=27
print(x)
b=28.75
is_present=True
# Out:
# 27

# %%
age = input("Enter your age:")
print(age)
# Out:
# Enter your age:18
# 18

# %%
x=25
y=str(x)
print(5*y)
# Out:
# 2525252525

# %%
val =int( input("enter your value")) #unknown always a string
val1=val*5 #takes 5times
print(val1)
# Out:
# enter your value25
# 125

# %% [markdown]
# input always takes in string

# %%
name=input("enter your name")
print("hello"+name)
print(name)
no1=int(input("enter the no 1 "))
no2=int(input("enter thr no 2 "))
no3=str(no1+no2)
no4=str(no1*no2)
print("addition"+no3)
print("product"+no4)
# Out:
# enter your nameatr
# helloatr
# atr
# enter the no 1 1
# enter thr no 2 2
# 3
# 2

# %%
i=10
while i>0:
   print("A")
   i=i-1
print("Done :)")
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# Done

# %%
event_name= "Machine Learning Accelerator Summit 3.0"
event_name.upper()
event_name.find("e")
event_name.replace("Machine Learning","ML")
# Out:
# 'ML Accelerator Summit 3.0'

# %%
price=600
if price>2500:
   print("Discounted price " + (str)(price-500))
elif price>1000:
   print("Discounted price "+str(price*0.85))
else:
  print("No Discount")
i
# Out:
# No Discount

# %%
user_name=input("Enter your name ")
price=(int)(input("The price of bought goods is "))
print("Hey, "+user_name)
if price>2500:
  print("Discunted price"+(str)(0.75*price))
elif price>2000:
  print("Discounted price"+(str)(0.8*price))
elif price>1500:
  print("Discunted price"+(str)(0.85*price))
elif price>1000:
  print("Discounted price"+(str)(price*0.9))
else:
  print("No Discount")
# Out:
# Enter your name AtrijRoy
# The price of bought goods is 1200
# Hey, AtrijRoy
# Discounted price1080.0

# %%
print('str')#problem only if ' in writing
# Out:
# str
